# %% [markdown]
# https://scikit-learn.org/stable/modules/biclustering.html

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/bicluster/plot_spectral_coclustering.html#sphx-glr-auto-examples-bicluster-plot-spectral-coclustering-py

# %%
import numpy as np

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (3.5.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.37.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: six>=1.5 in c:\users\gaoyu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from matplotlib import pyplot as plt

# %%
from sklearn.datasets import make_biclusters

# %%
from sklearn.cluster import SpectralCoclustering

# %%
from sklearn.metrics import consensus_score

# %%
data, rows, columns = make_biclusters(
    shape = (300, 300),
    n_clusters=5,
    noise=5,
    shuffle=False,
    random_state=0,
    )

# %%
plt.matshow(
    data,
    cmap = plt.cm.Reds,
    )
plt.title('original data')
# Out:
# Text(0.5, 1.0, 'original data')

# %%
rng = np.random.RandomState(0)

# %%
row_idx = rng.permutation(data.shape[0])

# %%
col_idx = rng.permutation(data.shape[1])

# %%
data = data[row_idx][:,col_idx]

# %%
plt.matshow(
    data,
    cmap = plt.cm.Reds,
    )
plt.title('shuffled data')
# Out:
# Text(0.5, 1.0, 'shuffled data')

# %%
model = SpectralCoclustering(
    n_clusters=5,
    random_state=0,
    )

# %%
model.fit(data)
# Out:
# SpectralCoclustering(n_clusters=5, random_state=0)

# %%
biclusters = model.biclusters_

# %%
biclusters[0].shape
# Out:
# (5, 300)

# %%
biclusters[1].shape
# Out:
# (5, 300)

# %%
score = consensus_score(
    model.biclusters_,
    (
        rows[:,row_idx],
        columns[:,col_idx]
    )
    )

# %%
print(score)
# Out:
# 1.0

# %%
model.row_labels_.shape
# Out:
# (300,)

# %%
model.column_labels_.shape
# Out:
# (300,)

# %%
new_row_index = np.argsort(model.row_labels_)

# %%
new_column_index = np.argsort(model.column_labels_)

# %%
new_data = data[new_row_index][:,new_column_index]

# %%
plt.matshow(
    new_data,
    cmap = plt.cm.Reds,
    )
plt.title('after biclustering data')
# Out:
# Text(0.5, 1.0, 'after biclustering data')
